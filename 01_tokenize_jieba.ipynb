# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="jieba")
import jieba

# %%
text = "任康芃毕业于华中科技大学计算机系"

# %%
# 精确模式
jieba.lcut(text)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\istho\AppData\Local\Temp\jieba.cache
# Loading model cost 0.518 seconds.
# Prefix dict has been built successfully.
# ['任康芃', '毕业', '于', '华中科技大学', '计算机系']

# %%
# 全模式
jieba.lcut(text, cut_all=True)
# Out:
# ['任',
#  '康',
#  '芃',
#  '毕业',
#  '于华中',
#  '华中',
#  '华中科',
#  '华中科技',
#  '华中科技大学',
#  '中科',
#  '科技',
#  '大学',
#  '计算',
#  '计算机',
#  '计算机系',
#  '算机',
#  '系']

# %%
# 搜索引擎模式
jieba.lcut_for_search(text)
# Out:
# ['任康芃',
#  '毕业',
#  '于',
#  '华中',
#  '中科',
#  '科技',
#  '大学',
#  '华中科',
#  '华中科技大学',
#  '计算',
#  '算机',
#  '计算机',
#  '计算机系']
